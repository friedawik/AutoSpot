# %%
import matplotlib.pyplot as plt
import cv2

# %%
image_name ="MF_MaxIP_3ch_2_000_230623_544_84_F_XY4_x6_y5_predictions"
image_path = 'plots/patches/' + image_name + '.png'
img = cv2.imread(image_path,  cv2.IMREAD_UNCHANGED)
plt.imshow(img)

# %%
image_path
# Out:
# '../plots/patches/MF_MaxIP_3ch_2_000_230623_544_84_F_XY4_x6_y5_predictions.png'
